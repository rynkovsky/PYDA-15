# %%
import pandas as pd
import numpy as np
from datetime import datetime

from tqdm.notebook import tqdm

import matplotlib.pyplot as plt

# %matplotlib inline

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.neighbors import KNeighborsRegressor

# %%
links = pd.read_csv('E:\\Python\\RSML-2\\RSML_HW1\\links.csv')
movies = pd.read_csv('E:\\Python\\RSML-2\\RSML_HW1\\movies.csv')
ratings = pd.read_csv('E:\\Python\\RSML-2\\RSML_HW1\\ratings.csv')
tags = pd.read_csv('E:\\Python\\RSML-2\\RSML_HW1\\tags.csv')

# %%
tags.head(20)
# Out:
#     userId  movieId                tag   timestamp
# 0        2    60756              funny  1445714994
# 1        2    60756    Highly quotable  1445714996
# 2        2    60756       will ferrell  1445714992
# 3        2    89774       Boxing story  1445715207
# 4        2    89774                MMA  1445715200
# 5        2    89774          Tom Hardy  1445715205
# 6        2   106782              drugs  1445715054
# 7        2   106782  Leonardo DiCaprio  1445715051
# 8        2   106782    Martin Scorsese  1445715056
# 9        7    48516       way too long  1169687325
# 10      18      431          Al Pacino  1462138765
# 11      18      431           gangster  1462138749
# 12      18      431              mafia  1462138755
# 13      18     1221          Al Pacino  1461699306
# 14      18     1221              Mafia  1461699303
# 15      18     5995          holocaust  1455735472
# 16      18     5995         true story  1455735479
# 17      18    44665       twist ending  1456948283
# 18      18    52604    Anthony Hopkins  1457650696
# 19      18    52604    courtroom drama  1457650711

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
def change_string(s):
    return ' '.join(s.replace(' ', '').replace('-','').split('|'))

# %%
movie_genres = [change_string(g) for g in movies.genres.values]

# %%
movie_genres[:20]
# Out:
# ['Adventure Animation Children Comedy Fantasy',
#  'Adventure Children Fantasy',
#  'Comedy Romance',
#  'Comedy Drama Romance',
#  'Comedy',
#  'Action Crime Thriller',
#  'Comedy Romance',
#  'Adventure Children',
#  'Action',
#  'Action Adventure Thriller',
#  'Comedy Drama Romance',
#  'Comedy Horror',
#  'Adventure Animation Children',
#  'Drama',
#  'Action Adventure Romance',
#  'Crime Drama',
#  'Drama Romance',
#  'Comedy',
#  'Comedy',
#  'Action Comedy Crime Drama Thriller']

# %%
# добавим тэги
movies_with_tags = movies.join(tags.set_index('movieId'), on='movieId')

# %%
movies_with_tags.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#    userId               tag     timestamp
# 0   336.0             pixar  1.139046e+09
# 0   474.0             pixar  1.137207e+09
# 0   567.0               fun  1.525286e+09
# 1    62.0           fantasy  1.528844e+09
# 1    62.0  magic board game  1.528844e+09

# %%
movies_with_tags.tag.unique()
# Out:
# array(['pixar', 'fun', 'fantasy', ..., 'star wars', 'gintama', 'remaster'],
#       dtype=object)

# %%
movies_with_tags.dropna(inplace=True)

# %%
tag_strings = []
movies2 = []

for movie, group in tqdm(movies_with_tags.groupby('title')):
    tag_strings.append(' '.join([str(s).replace(' ', '').replace('-', '') for s in group.tag.values]))
    movies2.append(movie)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1572.0), HTML(value='')))

# %%
movies_tags = pd.DataFrame(list(zip(movies2,tag_strings)), columns=['title', 'tag'])
movies_genres_tags = movies.join(movies_tags.set_index('title'), on='title')
movies_genres_tags['genres'] = movies_genres_tags['genres'].apply(change_string)
movies_genres_tags = movies_genres_tags.dropna()
movies_genres_tags.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 4        5  Father of the Bride Part II (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres  \
# 0  Adventure Animation Children Comedy Fantasy
# 1                   Adventure Children Fantasy
# 2                               Comedy Romance
# 4                                       Comedy
# 6                               Comedy Romance
#
#                                          tag
# 0                            pixar pixar fun
# 1  fantasy magicboardgame RobinWilliams game
# 2                                  moldy old
# 4                           pregnancy remake
# 6                                     remake

# %% [markdown]
# # Строим рекомедацию на жанрах

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(movies_genres_tags.genres.values)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
neig_reg = KNeighborsRegressor(n_neighbors=10, n_jobs=-1, metric='manhattan')
neig_reg.fit(X_train_counts, X_train_tfidf)
# Out:
# KNeighborsRegressor(metric='manhattan', n_jobs=-1, n_neighbors=10)

# %%
test = change_string('Adventure|Comedy|Fantasy|Crime')

predict = count_vect.transform([test])
X_tfidf = tfidf_transformer.transform(predict)

predicted_movies = neig_reg.kneighbors(X_tfidf, return_distance=True)
predicted_movies
# Out:
# (array([[1.76082037, 1.76082037, 1.76082037, 1.76082037, 1.76082037,
#          1.76542145, 1.96404785, 2.05017702, 2.05017702, 2.05017702]]),
#  array([[ 624, 1516,  939,  875,  945, 1262,  217,  653, 1296,  275]],
#        dtype=int64))

# %% [markdown]
# # Строим рекомедацию на тегах

# %%
movies_genres_tags.tag
# Out:
# 0                                    pixar pixar fun
# 1          fantasy magicboardgame RobinWilliams game
# 2                                          moldy old
# 4                                   pregnancy remake
# 6                                             remake
#                             ...
# 9681                      Comedy funny RachelMcAdams
# 9692    adventure AliciaVikander videogameadaptation
# 9709                 JoshBrolin RyanReynolds sarcasm
# 9710                           EmiliaClarke starwars
# 9732                   anime comedy gintama remaster
# Name: tag, Length: 1574, dtype: object

# %%
count_vect_tags = CountVectorizer()
X_train_counts2 = count_vect_tags.fit_transform(movies_genres_tags.tag.values)

# %%
tfidf_tags_transformer = TfidfTransformer()
X_train_tfidf2 = tfidf_tags_transformer.fit_transform(X_train_counts2)

# %%
neig_reg_tags = KNeighborsRegressor(n_neighbors=10, n_jobs=-1, metric='manhattan')
neig_reg_tags.fit(X_train_counts2, X_train_tfidf2)
# Out:
# KNeighborsRegressor(metric='manhattan', n_jobs=-1, n_neighbors=10)

# %%
test_tags = 'mafia funny L.A.'

predict_tags = count_vect_tags.transform([test_tags])
X_tfidf2_tags = tfidf_tags_transformer.transform(predict_tags)

res_tags = neig_reg_tags.kneighbors(X_tfidf2_tags, return_distance=True)
res_tags
# Out:
# (array([[0.9269027 , 0.9269027 , 0.9269027 , 0.9269027 , 0.9269027 ,
#          0.9269027 , 0.9269027 , 1.41232319, 1.41232319, 2.0730973 ]]),
#  array([[ 528,  301,  180,    7,  322,  526,  398,  673,  990, 1558]],
#        dtype=int64))

# %%
tfidf_transformer3 = TfidfVectorizer()
tfidf_transformer3.fit(movies_genres_tags['genres'])
# Out:
# TfidfVectorizer()

# %%
with_ratings = movies_genres_tags.merge(ratings)

# %%
for_model_df = with_ratings[with_ratings['userId']==75]
for_model_df
# Out:
#        movieId                                              title  \
# 1597        47                        Seven (a.k.a. Se7en) (1995)
# 3859       260          Star Wars: Episode IV - A New Hope (1977)
# 8265       515                     Remains of the Day, The (1993)
# 8809       541                                Blade Runner (1982)
# 9585       589                  Terminator 2: Judgment Day (1991)
# 9970       592                                      Batman (1989)
# 12754      903                                     Vertigo (1958)
# 12920      908                          North by Northwest (1959)
# 13075      912                                  Casablanca (1942)
# 13405      920                          Gone with the Wind (1939)
# 13568      924                       2001: A Space Odyssey (1968)
# 13685      928                                     Rebecca (1940)
# 14874     1090                                     Platoon (1986)
# 15809     1196  Star Wars: Episode V - The Empire Strikes Back...
# 16162     1198  Raiders of the Lost Ark (Indiana Jones and the...
# 16350     1200                                      Aliens (1986)
# 16593     1204                          Lawrence of Arabia (1962)
# 17301     1214                                       Alien (1979)
# 18133     1234                                  Sting, The (1973)
# 18249     1240                             Terminator, The (1984)
# 18781     1253              Day the Earth Stood Still, The (1951)
# 19155     1266                                  Unforgiven (1992)
# 19864     1291          Indiana Jones and the Last Crusade (1989)
# 20711     1372      Star Trek VI: The Undiscovered Country (1991)
# 20755     1374             Star Trek II: The Wrath of Khan (1982)
# 20815     1376               Star Trek IV: The Voyage Home (1986)
# 22168     1610                   Hunt for Red October, The (1990)
# 22507     1653                                     Gattaca (1997)
# 23050     1721                                     Titanic (1997)
# 24211     1962                          Driving Miss Daisy (1989)
# 25060     2078                            Jungle Book, The (1967)
# 25320     2115        Indiana Jones and the Temple of Doom (1984)
# 27027     2467  Name of the Rose, The (Name der Rose, Der) (1986)
# 27264     2529                          Planet of the Apes (1968)
# 27376     2571                                 Matrix, The (1999)
# 27817     2628   Star Wars: Episode I - The Phantom Menace (1999)
# 27949     2640                                    Superman (1978)
# 30972     3176                    Talented Mr. Ripley, The (1999)
# 34033     4306                                       Shrek (2001)
# 35519     4993  Lord of the Rings: The Fellowship of the Ring,...
# 35820     5008                 Witness for the Prosecution (1957)
# 36248     5445                             Minority Report (2002)
# 37036     5952      Lord of the Rings: The Two Towers, The (2002)
# 39171     6870                                Mystic River (2003)
# 39720     7153  Lord of the Rings: The Return of the King, The...
# 40543     8360                                     Shrek 2 (2004)
# 41435     8961                            Incredibles, The (2004)
# 42331    33493  Star Wars: Episode III - Revenge of the Sith (...
# 42529    34405                                    Serenity (2005)
#
#                                                   genres  \
# 1597                                    Mystery Thriller
# 3859                              Action Adventure SciFi
# 8265                                       Drama Romance
# 8809                               Action SciFi Thriller
# 9585                                        Action SciFi
# 9970                               Action Crime Thriller
# 12754                     Drama Mystery Romance Thriller
# 12920          Action Adventure Mystery Romance Thriller
# 13075                                      Drama Romance
# 13405                                  Drama Romance War
# 13568                              Adventure Drama SciFi
# 13685                     Drama Mystery Romance Thriller
# 14874                                          Drama War
# 15809                             Action Adventure SciFi
# 16162                                   Action Adventure
# 16350                      Action Adventure Horror SciFi
# 16593                                Adventure Drama War
# 17301                                       Horror SciFi
# 18133                                       Comedy Crime
# 18249                              Action SciFi Thriller
# 18781                               Drama SciFi Thriller
# 19155                                      Drama Western
# 19864                                   Action Adventure
# 20711                               Action Mystery SciFi
# 20755                    Action Adventure SciFi Thriller
# 20815                             Adventure Comedy SciFi
# 22168                          Action Adventure Thriller
# 22507                               Drama SciFi Thriller
# 23050                                      Drama Romance
# 24211                                              Drama
# 25060                  Animation Children Comedy Musical
# 25320                           Action Adventure Fantasy
# 27027                       Crime Drama Mystery Thriller
# 27264                                 Action Drama SciFi
# 27376                              Action SciFi Thriller
# 27817                             Action Adventure SciFi
# 27949                             Action Adventure SciFi
# 30972                             Drama Mystery Thriller
# 34033  Adventure Animation Children Comedy Fantasy Ro...
# 35519                                  Adventure Fantasy
# 35820                             Drama Mystery Thriller
# 36248                Action Crime Mystery SciFi Thriller
# 37036                                  Adventure Fantasy
# 39171                                Crime Drama Mystery
# 39720                     Action Adventure Drama Fantasy
# 40543  Adventure Animation Children Comedy Musical Ro...
# 41435         Action Adventure Animation Children Comedy
# 42331                             Action Adventure SciFi
# 42529                             Action Adventure SciFi
#
#                                                      tag  userId  rating  \
# 1597                    mystery twistending serialkiller      75     2.0
# 3859   classic spaceaction action scifi EPIC greatsou...      75     5.0
# 8265                                  Butler Housekeeper      75     2.0
# 8809   scifi robots androids artificialintelligence a...      75     4.0
# 9585   apocalypse ArnoldSchwarzenegger nuclearwar sci...      75     4.5
# 9970                                           superhero      75     3.5
# 12754  falling AlfredHitchcock Atmospheric imdbtop250...      75     1.0
# 12920           MountRushmore AlfredHitchcock imdbtop250      75     4.5
# 13075                        startofabeautifulfriendship      75     4.0
# 13405                                           CivilWar      75     3.0
# 13568  Hal space aliens apes ArthurC.Clarke artificia...      75     3.5
# 13685                                       Mrs.DeWinter      75     4.5
# 14874                                            Vietnam      75     1.0
# 15809  Iamyourfather space spaceopera classic GeorgeL...      75     4.5
# 16162  adventure archaeology indianajones StevenSpiel...      75     4.5
# 16350  action aliens horror scifi space spacecraft SP...      75     2.5
# 16593                                         MiddleEast      75     3.5
# 17301                                             aliens      75     4.5
# 18133                                     TheEntertainer      75     4.5
# 18249  Action artificialintelligence robots SciFi spe...      75     4.0
# 18781                                             aliens      75     4.0
# 19155                                            revenge      75     4.0
# 19864                              archaeology HolyGrail      75     4.5
# 20711                                           Klingons      75     4.0
# 20755                                        CaptainKirk      75     2.0
# 20815                                             whales      75     4.0
# 22168                                          TomClancy      75     4.0
# 22507                future intelligent thoughtprovoking      75     2.0
# 23050                                  shipwreck romance      75     2.5
# 24211                                             rasicm      75     4.5
# 25060                                             Disney      75     5.0
# 25320                                        archaeology      75     3.5
# 27027                                           religion      75     4.0
# 27264                                        twistending      75     1.5
# 27376  martialarts scifi alternateuniverse philosophy...      75     1.0
# 27817                                   prequel theForce      75     1.0
# 27949                                          superhero      75     1.5
# 30972  basedonabook creepy disturbing JudeLaw murder ...      75     1.0
# 34033                                         fairytales      75     4.0
# 35519  fantasy highfantasy Magic mythology tolkien wi...      75     5.0
# 35820                               AgathaChristie court      75     4.0
# 36248                                             future      75     2.0
# 37036                                       Myth Tolkein      75     4.0
# 39171                              childabuse kidnapping      75     1.0
# 39720  Adventure ensemblecast fantasy fantasyworld gr...      75     4.0
# 40543                                              ogres      75     4.0
# 41435         Disney superhero animation SamuelL.Jackson      75     4.0
# 42331                                   space spaceopera      75     0.5
# 42529                                predictable Firefly      75     4.0
#
#         timestamp
# 1597   1158968272
# 3859   1158989756
# 8265   1158989888
# 8809   1158989785
# 9585   1158989827
# 9970   1158989896
# 12754  1158968143
# 12920  1158967045
# 13075  1158967840
# 13405  1158967791
# 13568  1158967613
# 13685  1158967852
# 14874  1158967824
# 15809  1158990239
# 16162  1158990045
# 16350  1158967713
# 16593  1158989794
# 17301  1158967602
# 18133  1158967139
# 18249  1158990196
# 18781  1158982941
# 19155  1158967216
# 19864  1158990090
# 20711  1158968308
# 20755  1158967591
# 20815  1158967212
# 22168  1158989841
# 22507  1158967079
# 23050  1158967893
# 24211  1158967875
# 25060  1158982700
# 25320  1158990116
# 27027  1158989849
# 27264  1158967238
# 27376  1158967564
# 27817  1158967457
# 27949  1158967058
# 30972  1158968301
# 34033  1158982794
# 35519  1158967649
# 35820  1158968122
# 36248  1158967067
# 37036  1158982929
# 39171  1158968174
# 39720  1158967110
# 40543  1158982806
# 41435  1158982785
# 42331  1158967510
# 42529  1158967581

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
X, y = tfidf_transformer3.transform(for_model_df['genres']), for_model_df['rating']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([3.06072253, 3.84845852, 3.01175606, 2.94917055, 4.25259453,
#        3.20127224, 1.74701464, 1.6962854 , 3.03518835, 2.04355448])

# %%
y_test
# Out:
# 35820    4.0
# 39171    1.0
# 12754    1.0
# 9970     3.5
# 39720    4.0
# 22168    4.0
# 17301    4.5
# 18781    4.0
# 15809    4.5
# 8809     4.0
# Name: rating, dtype: float64

# %% [markdown]
# # Оценить RMSE на тестовой выборке

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-b430784a2a4d> in <module>
# ----> 1 mean_squared_error(y_test, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     254         y_true, y_pred, multioutput)
#     255     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     254     uniques = np.unique(lengths)
#     255     if len(uniques) > 1:
# --> 256         raise ValueError("Found input variables with inconsistent numbers of"
#     257                          " samples: %r" % [int(l) for l in lengths])
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [10, 39]
